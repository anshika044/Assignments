# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/homeprices.csv")
df.head()
# Out:
#      area     price  tea_coffee
# 0  2600.0  550000.0           0
# 1  3000.0  565000.0           1
# 2  3200.0  610000.0           0
# 3     NaN  680000.0           1
# 4  4000.0       NaN           0

# %%
df.shape
# Out:
# (6, 3)

# %%
df
# Out:
#      area     price  tea_coffee
# 0  2600.0  550000.0           0
# 1  3000.0  565000.0           1
# 2  3200.0  610000.0           0
# 3     NaN  680000.0           1
# 4  4000.0       NaN           0
# 5  5000.0  825000.0           1

# %%
#Dealing with missing values
df['area'].fillna(df['area'].mean(),inplace = True)
df
# Out:
#      area     price  tea_coffee
# 0  2600.0  550000.0           0
# 1  3000.0  565000.0           1
# 2  3200.0  610000.0           0
# 3  3560.0  680000.0           1
# 4  4000.0       NaN           0
# 5  5000.0  825000.0           1

# %%
df['price'].fillna(df['price'].mean(),inplace = True)
df
# Out:
#      area     price  tea_coffee
# 0  2600.0  550000.0           0
# 1  3000.0  565000.0           1
# 2  3200.0  610000.0           0
# 3  3560.0  680000.0           1
# 4  4000.0  646000.0           0
# 5  5000.0  825000.0           1

# %%
#Droping the unwanted Columns
df.drop(columns = ['tea_coffee'],inplace = True)

# %%
df
# Out:
#      area     price
# 0  2600.0  550000.0
# 1  3000.0  565000.0
# 2  3200.0  610000.0
# 3  3560.0  680000.0
# 4  4000.0  646000.0
# 5  5000.0  825000.0

# %%
plt.scatter(df['area'],df['price'])

# %%
#defining the I/P and O/P col
#X = df['area']
#X
#Throw an error in the  training part

# %%
#defining the I/P and O/P col
X = df[['area']].values
X
# Out:
# array([[2600.],
#        [3000.],
#        [3200.],
#        [3560.],
#        [4000.],
#        [5000.]])

# %%
y = df[['price']].values
y
# Out:
# array([[550000.],
#        [565000.],
#        [610000.],
#        [680000.],
#        [646000.],
#        [825000.]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
#Prediction Area >>3300
lr.predict([[4300]])
# Out:
# array([[729176.65198238]])
